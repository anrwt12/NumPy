# %% [markdown]
# <a href="https://colab.research.google.com/github/anrwt12/NumPy/blob/main/NumPy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#numpy >> numerical python
#2005  developed by Travis Oliphant
#before 2005 there were special mathematical tools ( similar to Tora, Lingo)

# %%
import numpy as np
# as  is alias

# %%
np.__version__

# %%
print(np.__doc__)

# %%
lis=[1,2,3,"pwskills",3+5j,True,1.2]
type(lis)
# list stores hetrogenous data

# %%
#NumPy is used because it makes numerical and mathematical operations fast, easy, and efficient in Python.
#Fast Computation NumPy works in C internally, so it is much faster than Python lists

# %%
# convert list to aaray
l=[1,2,3,4,5]

# %%
arr=np.array(l) # numpy.ndarray >> n dimensional array
#numpy stores homogenous data it can be int, string , float values

# %%
type(arr)

# %%
arr

# %%
l=[1,2,3,4,5,"pw skills"]

# %%
arr1=np.array(l)

# %%
arr1
# array store homogenous data
#here it have different data type array covert the data type into same data type into strings

# %%
type(arr1)

# %%
arr

# %%
l=[1,2,3,4,5,6.3]

# %%
arr2=np.array(l)

# %%
arr2

# %%
type(arr2)

# %%
arr2.ndim

# %%
arr4=np.array([[1,2,3],[4,5,6]])

# %%
arr4

# %%
arr4.ndim

# %%
mat=np.matrix([1,2,3,4]) # matrix is a specialised array of 2 dimension

# %%
type(mat)

# %%
mat.ndim

# %%
mat

# %%
#To understand the dimension, see the no of opening/closing square bracket

# %%
np.matrix([[[1,2],[4,5]],[6,7]])# it will show error because matris is always 2 dimnesion

# %%
arr5=np.array([[[1,2],[4,5],[6,7]]])

# %%
arr5

# %%
type(arr5)

# %%
arr5.ndim

# %%
#more ays to array
l=[1,2,3,4]
np.array(l)#intial function as array to convert to an array , np.array came after this

# %%
#another way
np.asanyarray([1,2,3])

# %%
#asanyarray will contert the input to an ndarray , but pass ndarray
#subclasses through
#if something is already an array or part of array, it will simply allow to pass through it

# %%
np.asanyarray([1,3,4])

# %%
mat

# %%
np.asanyarray(mat)

# %%
t=([1,2,3],[4,5,6])

# %%
type(t)

# %%
np.array(t)

# %%
arr

# %%
#accessing element of the array

# %%
arr[3]

# %%
arr[0]=100

# %%
arr

# %%
arr[1]

# %%
#a and arr will point to same memory location , so if there is change is a or arr
#it will reflect on both

# %%
a=arr

# %%
a

# %%
arr

# %%
a[0]=300

# %%
a

# %%
arr

# %%
#to create an array>> np.array, np.asarray , np.asany array

# %%
#multiple approaches to generate any array

# %%
arr8=np.fromfunction(lambda i,j: i==j,(3,3))# construct an array by executing a function over each coordinate

# %%
1==1

# %%
1==2

# %%
arr8

# %%
arr8.ndim

# %%
arr8.shape # shape of array

# %%
arr8.size # no of size

# %%
#True is stored as 1 and False is stored as 0 in python

# %%
arr9=np.fromfunction(lambda i,j: i*j , (3,3))

# %%
arr9.size

# %%
arr9.shape

# %%
arr9.ndim

# %%
for i in range(5):
  print(i)

# %%
[i for i in range(5)]

# %%
list(i for i in range(5))

# %%
iterator = (i for i in range (5))

# %%
iterator

# %%
np.fromiter(iterator,int) # create a new 1-dimensional array from an iterable object.

# %%
np.fromstring('22 23 24', sep=" ")

# %%
np.fromstring('22 23 24', sep=" ", dtype= int )#by default is a float  values inside should be integer

# %%
#for string character you have to use split
string="Anjali, Ekta, Mani"
string.split(" ,")

# %%
#for string character you have to use split
string = "Ajay, Bijay, Sanjay"
string.split(",")

# %%
np.array(string.split(","))

# %%
range(0,10)

# %%
list(range(0,10))

# %%
#other method of numpy >> To generate a sequence of number
np.arange(1, 10) #arange returns evenly spacified values within a given interval, by default step is 1

# %%
np.arange(1,10,0.1)

# %%
np.linspace(1,5,10)# give me 10 numbers between 1 and 5
